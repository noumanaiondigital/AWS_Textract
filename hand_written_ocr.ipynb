# %%
# !pip install rapidfuzz
# !pip install boto3
# Out:
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (1.27.1)
# Requirement already satisfied: botocore<1.31.0,>=1.30.1 in /usr/local/lib/python3.10/dist-packages (from boto3) (1.30.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3) (0.6.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.31.0,>=1.30.1->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.31.0,>=1.30.1->boto3) (1.26.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.31.0,>=1.30.1->boto3) (1.16.0)

# %%
import boto3
import time
import itertools
import pandas as pd
import numpy as np
from datetime import datetime
from rapidfuzz import fuzz
import json

runtime = True

# %% [markdown]
# # **Paths and Variables**

# %%
access_key_id = your_access_key_id
secret_access_key = your_access_key
aws_region = "us-east-2"
bucket_name = "talebtext"
bucket_key = "test.pdf"
file_path = "/content/no_blank_image_table_sample-1.pdf"

# %% [markdown]
# # **Upload File on S3 Bucket**
# Below two cells are used to upload your pdf file on AWS S3 Bucket.
# Note: To run AWS Tesseract, it is necessary to upload files on S3 Bucket.
#
# **Run this code (below 2 cells) only once to upload file.**

# %%
with open(file_path, "rb") as f:
  bytes_read = f.read()

# %%
s3_client = boto3.client(
    's3',
    aws_access_key_id= access_key_id,
    aws_secret_access_key= secret_access_key,
    region_name=aws_region
)

s3_client.put_object(Body=bytes_read,
                  Bucket=bucket_name,
                  Key=bucket_key)
print("File Uploaded Successfully.")
# Out:
# File Uploaded Successfully.

# %% [markdown]
# # **Textract Service**

# %%
#Initialze AWS Tesseract service object using boto3 client
textract_client = boto3.client(
    'textract',
    aws_access_key_id= access_key_id,
    aws_secret_access_key= secret_access_key,
    region_name=aws_region
)

# %%
def start_job():
  # This method starts the document analysis asynchronously and returns a job id in response.
    try:
        response = textract_client.start_document_analysis(
            DocumentLocation={
                'S3Object': {
                    'Bucket': bucket_name,
                    'Name': bucket_key
                }},
            FeatureTypes=['TABLES'])
        return response["JobId"]
    except Exception as e:
        print("Failed to start job: {}".format(e))

def is_job_complete(job_id):
  # This method checks the status of the job submitted to AWS Tesseract for analysis using the JobID.
    try:
        time.sleep(1)
        response = textract_client.get_document_analysis(JobId=job_id)
        status = response["JobStatus"]
        print("Job status: {}".format(status))

        while status == "IN_PROGRESS":
            time.sleep(1)
            response = textract_client.get_document_analysis(JobId=job_id)
            status = response["JobStatus"]
            print("Job status: {}".format(status))

        return status
    except Exception as e:
        print("Failed to get job status: {}".format(e))

def get_job_results(job_id):
  #This method fetches the results from the successful AWS Tesseract Job.
    try:
        pages: list = []
        time.sleep(1)
        response = textract_client.get_document_analysis(JobId=job_id)
        pages.append(response)
        print("Paginated resultset received: {}".format(len(pages)))
        next_token = None
        if 'NextToken' in response:
            next_token = response['NextToken']

        while next_token:
            time.sleep(1)
            response = textract_client.\
                get_document_analysis(JobId=job_id, NextToken=next_token)
            pages.append(response)
            print("Result set page received: {}".format(len(pages)))
            next_token = None
            if 'NextToken' in response:
                next_token = response['NextToken']

        return pages
    except Exception as e:
        print("Failed to get job result: {}".format(e))

def submit_job():
  #This method initiates the AWS Job and and collects result.
    try:
        response: list = []
        job_id = start_job()
        print("Started job with id: {}".format(job_id))
        if is_job_complete(job_id):
            result = get_job_results(job_id)
            response.append(result)

        return response
    except Exception as e:
        print("Failed to submit job to textract: {}".format(e))

# %%
result = submit_job()
# Out:
# Started job with id: 4a1a62b49ead786f867e8b6a1b143840c95beea0a105f3e33b0574f1c6374ee6
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Paginated resultset received: 1
# Result set page received: 2

# %%
#Store result in File
json_file_path = "tesseract_result.json"

# Write the JSON object to the file
import json
with open(json_file_path, 'w') as f:
    json.dump(result, f)

print("JSON data has been stored in the file:, please download/save it on your local system for later use.", file_path)
# Out:
# JSON data has been stored in the file:, please download/save it on your local system for later use. /content/no_blank_image_table_sample-1.pdf

# %%
result
# Out:
# [[{'DocumentMetadata': {'Pages': 4},
#    'JobStatus': 'SUCCEEDED',
#    'NextToken': 'p3StR2NSiBmeqocxSUQfKDk+wWKfC5G7d4XYjqHMhmO9B2HHBfr2mzVu76Gt1j0w4J76JMVMg2jjW5s+sfni9c+wovbJf+v1+UUC2+NDOhujUr5oLkGN0hxpFJUg2gbAl2fEl2w=',
#    'Blocks': [{'BlockType': 'PAGE',
#      'Geometry': {'BoundingBox': {'Width': 1.0,
#        'Height': 1.0,
#        'Left': 0.0,
#        'Top': 0.0},
#       'Polygon': [{'X': 0.0, 'Y': 9.629952835155109e-09},
#        {'X': 1.0, 'Y': 0.0},
#        {'X': 1.0, 'Y': 1.0},
#        {'X': 0.0, 'Y': 1.0}]},
#      'Id': 'c6b32617-23c2-42a2-95c6-2bb73f400297',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['148a2a41-be74-441a-987d-7cc89a3060a0',
#         '5e776070-e253-4ce1-bc8b-bba46c32a865',
#         'cc4c2f75-d8c8-4a89-ac01-1b2c6773e694',
#         'f20e21b7-170b-4fd1-b330-b3d397f49f18',
#         '4a3042e8-9ca4-4c41-a606-39b0bebb596b',
#         'ba1297fd-f4bc-4a81-8955-cb46dde3a88d',
#         '354f8ae2-e8d6-4891-add1-d9309b9192a0',
#         'ef439a34-0411-4c86-9da3-a847ec834073',
#         'dbaf592d-21b1-408c-8b87-e5fc2aebf7ed',
#         'ea31d90c-4ac3-4d23-abcb-f0e3d8b46ce8',
#         '686a74ef-99fe-4e02-8e79-d60131db7ae1',
#         'b135a502-aab0-4862-b0f4-52bf9fb7e8c1',
#         '3cd2a32f-af98-4f0b-b9db-49f7f779fa1c',
#         '90635fec-e2f8-4951-b494-de5e1da2879e',
#         '51d5f63b-a5f3-48e3-96c7-c5e87d37ce2e',
#         '1b35301c-ac36-4e4b-9f7b-584249e3cfb7',
#         '8694e261-5eb7-421e-922b-e6ec2ac3c072',
#         '0dd96240-1c52-4903-bc3c-0ba4b2dbed48',
#         '47982166-b769-4660-9e53-bca33396dd27',
#         'd6b92849-6942-4361-9bd0-8bcc9502274c',
#         '5ee0e0fd-b48a-46d6-85c5-48c5df543ae8',
#         '67a89d60-be7c-42fb-8957-68822db227be',
#         '56c698a0-204c-46dd-9311-fb414ab1054a',
#         'cf28edfe-0461-46c6-a0c9-3e20703e57e4',
#         'e1cfcb99-8a52-40cc-abb8-8ef6b2e306e4',
#         'ce1bf7aa-77bf-4133-8c33-3cd2eba5b0ef',
#         'c175051c-ba03-43e5-8763-60a7da08a78c',
#         'faffa067-171b-420b-b644-43ae40dc5ba2',
#         'bbce4014-0dab-46e7-8d02-f83c3d0541a8',
#         '0b67b69f-d529-4a8a-88fb-84c61aed2f7e',
#         '33d0e593-bc9a-49f2-844b-b97bb4ba96b2',
#         'e567fd7e-3bd3-498f-a5f9-748da87654f3',
#         '21e231d4-3ef8-4368-8c1e-b7b3820a8075',
#         '34a1ea93-2518-4b73-b9dc-9b9d1df3aca7',
#         'c22e41c3-a90b-4f45-bf45-c6d4903fe32c',
#         'bfd10c74-a986-44ab-87cc-afb816d58387',
#         'b8eaf0ab-8d51-453f-92ef-16a4fdb3c051',
#         'f630c3a2-4081-4414-8a7a-556aa1683369',
#         'b84bd54d-6e4b-4df0-b26a-30cb713801e1',
#         '74fa10fe-03ce-46cd-becf-496a0d0efdd4',
#         '5508e1a6-add4-402b-935f-fe95027804ff',
#         '8558993f-1ec1-4ea0-9542-8fd443d1e2a4',
#         '03995ac8-4771-46b5-b652-1926db539a84',
#         '9de85ee4-9071-4304-9f3d-78099a7de964',
#         'b21eaa08-0eac-4c72-b6ec-965836fd0d68',
#         '78a47654-6b4a-4252-9fa3-5ed091c7d180',
#         '3d19f741-eaa1-400e-90b2-88a1110371af',
#         '09cf7600-98ec-4528-9aa9-f215c02299b9',
#         'b9a43c33-c736-48dc-b23c-f265ab635e07',
#         '474da77e-df58-4599-b926-dac9ac8f7faa',
#         'b5a6bf0f-d64d-4c1f-b2aa-3d92ad67caf3',
#         'ed5dfe08-7e88-4a61-8ff3-4afd2d994030',
#         '2d22b62c-576e-4d5e-8034-81986e291a4f',
#         'd537b3f7-d073-4ec8-9892-19b5988284ff',
#         '62b726b2-e46b-4557-aa3a-d1eb35429113',
#         'f04cbb5b-e7fb-491d-a7f5-34336de6dd13',
#         '7a9f7a8c-4adc-4c7b-b540-ef0e789a3de7',
#         '2e9a01ef-13a6-4200-95cd-3c122ab16dc2',
#         '1c418956-ffe3-4e4b-ab1b-03ae61a86ba0',
#         'c7930a2e-588f-4c3b-bc1f-788ffe8bcfce',
#         'bc664fcc-6069-4831-8f09-c2b664b53dd5',
#         'be00789c-b6a4-4d55-9f37-1a9fb1c65c29',
#         '75d8be9b-c645-4a07-aa23-90e4e5b10376',
#         'e26f96c7-7abc-4978-af8c-758bb090b866',
#         'bd2538cf-0c01-4e54-99cf-826dc4c7c0e9',
#         '6d7f670f-8d2b-4e91-91f8-9e93ee3098cd',
#         'a6f55e89-5984-48e0-98e1-6f6865efbac6',
#         'db4f1a07-0f5f-4ef8-a8d5-20b6d9c9be4d',
#         '55673dd1-9599-4fe1-ab8b-e95cd23ae09c',
#         '2e2e8351-1c7b-4dd1-8a52-6949fa2340eb',
#         '77f458a2-2190-4d92-9f0b-51def5db60f7',
#         '39ff7e9c-47a4-4e59-aca3-bb801df47501',
#         'b95e13f7-08fa-4481-8e9a-e8176f0ac407',
#         '11fa22a9-1125-4eac-9b92-5f6bd573dd9b',
#         'a34daffd-edac-4b53-8bd8-695e8b48b57a',
#         'de7c1b23-592d-4e33-a1b2-99dada75ae62',
#         '936c5f45-24db-46b2-971f-c07a8b4afd4f',
#         'c908d0cd-adc8-4423-ae9e-cc8915045261',
#         '3f9f8df4-01c4-4eba-b891-a717e4a0e6a4',
#         '54b01945-01cd-4736-97d2-efcb9065cd58',
#         '8b2e16ca-4ec4-4d7f-a2e0-3850b281bac1',
#         '151b4bb5-1c8d-4ea7-a148-7aadc6cdd967',
#         'cf765ad5-43fc-4fbf-a3f5-61913c4a0b2c',
#         '7da4da54-e0f5-4985-b02b-1799e985858a',
#         'd204cfc1-f769-4e90-8501-7c360434c18e',
#         '9e3dca50-14d2-4150-bb98-6d65fbd04565',
#         'ce80340b-2a5f-438e-bd2e-ec8eac2e6a98',
#         '97154d78-781f-42e5-99e5-b54286b84d19',
#         '1ddeb1fb-e845-4120-982a-9805d2609a2c',
#         '1d09d718-331d-4dc0-b840-3a6478820d61',
#         'f41774cf-05a0-40c2-b564-1195771d97d6',
#         'c06e40d6-1320-44b4-9c40-c816805d5cf5',
#         '19151523-90e4-4cf3-a4b1-0fc62bfac8e8',
#         '012038a6-af85-47c2-a21c-94b2ccda1743',
#         '6f901c8d-35be-4946-b366-394608a6dc97',
#         '480c2ba6-0b00-402b-ab5e-4c16b8e155e7',
#         '0b5ee01b-66fb-42ba-8021-2f6f3763b0f7',
#         '9461a3df-91be-4bcf-bceb-2a11f11e3269',
#         'c8f7cd4d-5ffe-4857-95fe-86afb4ee71c1',
#         'cf898dfd-318c-4d42-93fb-27b8c3a86416',
#         '880b1b07-135b-4967-937f-902f680825af',
#         'ffd1cf1d-1d48-4c06-adc1-0ea596a07792',
#         'a595ae73-d9c0-471f-8101-a41120666321',
#         'c74192fb-31eb-47af-ae40-43986e45103e',
#         'b282db58-fac0-4ecd-91e7-31406dd4d0c5',
#         '0f184e3e-790d-466d-9dc4-752d06abef2f',
#         '702e084c-6616-4188-bcd1-dee9fc542652',
#         '5ca99c0c-48d8-410f-a56b-c6849423ad4a',
#         '594a385c-bd6c-47f8-a850-b6e570886a64',
#         '46feaa46-514b-49d3-9729-cb72e9771aaa',
#         'a9232c6b-6199-4b60-aa5f-de2227a5f0af']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.90290832519531,
#      'Text': 'Solar Power Systems',
#      'Geometry': {'BoundingBox': {'Width': 0.15605290234088898,
#        'Height': 0.011500043794512749,
#        'Left': 0.41946643590927124,
#        'Top': 0.0862249881029129},
#       'Polygon': [{'X': 0.41946643590927124, 'Y': 0.08623262494802475},
#        {'X': 0.5755156874656677, 'Y': 0.0862249881029129},
#        {'X': 0.575519323348999, 'Y': 0.09771765768527985},
#        {'X': 0.41946956515312195, 'Y': 0.0977250337600708}]},
#      'Id': '148a2a41-be74-441a-987d-7cc89a3060a0',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['f23aa30a-b7af-47f2-a44c-34a144df2a45',
#         '51c0c5a2-6db2-4595-b52e-cb2865e9d717',
#         '6f1466d7-549f-4e2f-b654-e0dc30195a10']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.96949768066406,
#      'Text': 'Power Analysis',
#      'Geometry': {'BoundingBox': {'Width': 0.11339258402585983,
#        'Height': 0.011787393130362034,
#        'Left': 0.4409106373786926,
#        'Top': 0.1013733521103859},
#       'Polygon': [{'X': 0.4409106373786926, 'Y': 0.1013786569237709},
#        {'X': 0.5542995929718018, 'Y': 0.1013733521103859},
#        {'X': 0.5543032288551331, 'Y': 0.11315564066171646},
#        {'X': 0.4409139156341553, 'Y': 0.11316075176000595}]},
#      'Id': '5e776070-e253-4ce1-bc8b-bba46c32a865',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['a9b33169-f748-4e3a-8712-91e1b806c52d',
#         '075e4f7e-e0b0-4334-a202-b8eb67d30c24']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.82893371582031,
#      'Text': 'Data Log',
#      'Geometry': {'BoundingBox': {'Width': 0.06506664305925369,
#        'Height': 0.011217025108635426,
#        'Left': 0.4651761054992676,
#        'Top': 0.1174888163805008},
#       'Polygon': [{'X': 0.4651761054992676, 'Y': 0.1174917072057724},
#        {'X': 0.5302393436431885, 'Y': 0.1174888163805008},
#        {'X': 0.5302427411079407, 'Y': 0.1287030577659607},
#        {'X': 0.46517932415008545, 'Y': 0.12870584428310394}]},
#      'Id': 'cc4c2f75-d8c8-4a89-ac01-1b2c6773e694',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['4246e1f6-d66e-4625-96fa-cf0b313ce32f',
#         'f62b4a0e-495e-4fd6-adbd-ac877a70e029']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 97.30271911621094,
#      'Text': 'Date: 01. Jan.2022',
#      'Geometry': {'BoundingBox': {'Width': 0.20758356153964996,
#        'Height': 0.019269203767180443,
#        'Left': 0.12431146204471588,
#        'Top': 0.1311473399400711},
#       'Polygon': [{'X': 0.12431146204471588, 'Y': 0.13115616142749786},
#        {'X': 0.3318902254104614, 'Y': 0.1311473399400711},
#        {'X': 0.33189502358436584, 'Y': 0.1504083126783371},
#        {'X': 0.12431514263153076, 'Y': 0.1504165530204773}]},
#      'Id': 'f20e21b7-170b-4fd1-b330-b3d397f49f18',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['986f01e1-07b9-49be-8c0a-d0ac4c9a68b2',
#         '713df333-3d1a-454b-9a27-e671d04fc0ce',
#         '0aac9f09-33f2-45b3-af77-0c52334ba440']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.85807800292969,
#      'Text': 'Operator Name: Tee',
#      'Geometry': {'BoundingBox': {'Width': 0.17195002734661102,
#        'Height': 0.013295356184244156,
#        'Left': 0.12338278442621231,
#        'Top': 0.1486927717924118},
#       'Polygon': [{'X': 0.12338278442621231, 'Y': 0.14869964122772217},
#        {'X': 0.29532963037490845, 'Y': 0.1486927717924118},
#        {'X': 0.29533281922340393, 'Y': 0.16198158264160156},
#        {'X': 0.12338532507419586, 'Y': 0.16198812425136566}]},
#      'Id': '4a3042e8-9ca4-4c41-a606-39b0bebb596b',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['683e0b0e-34d3-4e70-a65a-e6d4a84070d5',
#         '05199f92-d664-4d09-837a-052ac3d98549',
#         'f24ad174-da27-4e91-be92-120c55faff16']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.72339630126953,
#      'Text': 'Operator Name 2: Tom',
#      'Geometry': {'BoundingBox': {'Width': 0.17652064561843872,
#        'Height': 0.012886789627373219,
#        'Left': 0.12352104485034943,
#        'Top': 0.16377094388008118},
#       'Polygon': [{'X': 0.12352104485034943, 'Y': 0.16377761960029602},
#        {'X': 0.300038605928421, 'Y': 0.16377094388008118},
#        {'X': 0.30004170536994934, 'Y': 0.17665138840675354},
#        {'X': 0.12352350354194641, 'Y': 0.17665773630142212}]},
#      'Id': 'ba1297fd-f4bc-4a81-8955-cb46dde3a88d',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['e357bfa6-350e-4b1a-a704-63e7ad8c092c',
#         'd4981d80-548e-40be-aa6b-1a1d3d09d0fa',
#         '3ecdb8f2-347b-4053-8977-5db0f18e5c8b',
#         'ca1d6bc7-2b64-46a3-8295-3c5180152445']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 93.78832244873047,
#      'Text': 'Operator Name 3: Sam',
#      'Geometry': {'BoundingBox': {'Width': 0.1932433694601059,
#        'Height': 0.013978605158627033,
#        'Left': 0.12321600317955017,
#        'Top': 0.17887476086616516},
#       'Polygon': [{'X': 0.12321600317955017, 'Y': 0.17888164520263672},
#        {'X': 0.3164559602737427, 'Y': 0.17887476086616516},
#        {'X': 0.31645938754081726, 'Y': 0.19284687936306},
#        {'X': 0.12321867048740387, 'Y': 0.19285336136817932}]},
#      'Id': '354f8ae2-e8d6-4891-add1-d9309b9192a0',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['64e0867b-99f4-4225-89dc-9c3dbd830247',
#         '2bd15810-2446-47b6-b0c8-59446a926743',
#         '83d54da5-5117-4675-8d68-db62ebcd8c4f',
#         '3913fa5c-2705-4068-9d0c-0f67b0b780f6']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.94612121582031,
#      'Text': '3rd',
#      'Geometry': {'BoundingBox': {'Width': 0.02455982007086277,
#        'Height': 0.009884681552648544,
#        'Left': 0.314949095249176,
#        'Top': 0.19583815336227417},
#       'Polygon': [{'X': 0.314949095249176, 'Y': 0.19583897292613983},
#        {'X': 0.33950644731521606, 'Y': 0.19583815336227417},
#        {'X': 0.33950892090797424, 'Y': 0.20572204887866974},
#        {'X': 0.31495150923728943, 'Y': 0.205722838640213}]},
#      'Id': 'ef439a34-0411-4c86-9da3-a847ec834073',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['9606f00a-7159-4fd3-a5a1-73916ade8cbd']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.95548248291016,
#      'Text': '1st',
#      'Geometry': {'BoundingBox': {'Width': 0.022302139550447464,
#        'Height': 0.009481929242610931,
#        'Left': 0.5066409707069397,
#        'Top': 0.19621185958385468},
#       'Polygon': [{'X': 0.5066409707069397, 'Y': 0.19621260464191437},
#        {'X': 0.5289402008056641, 'Y': 0.19621185958385468},
#        {'X': 0.5289430618286133, 'Y': 0.2056930810213089},
#        {'X': 0.5066437721252441, 'Y': 0.2056937962770462}]},
#      'Id': 'dbaf592d-21b1-408c-8b87-e5fc2aebf7ed',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['30e7265e-3ee8-403a-8cd8-a7f20b425dd1']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.96208953857422,
#      'Text': '2nd',
#      'Geometry': {'BoundingBox': {'Width': 0.027828997001051903,
#        'Height': 0.009558238089084625,
#        'Left': 0.6969189643859863,
#        'Top': 0.19589129090309143},
#       'Polygon': [{'X': 0.6969189643859863, 'Y': 0.19589221477508545},
#        {'X': 0.7247445583343506, 'Y': 0.19589129090309143},
#        {'X': 0.7247479557991028, 'Y': 0.20544864237308502},
#        {'X': 0.6969223022460938, 'Y': 0.20544952154159546}]},
#      'Id': 'ea31d90c-4ac3-4d23-abcb-f0e3d8b46ce8',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['397f93f2-6f61-4663-8cbc-98c62191298d']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.8202896118164,
#      'Text': 'System#1',
#      'Geometry': {'BoundingBox': {'Width': 0.07286014407873154,
#        'Height': 0.011733708903193474,
#        'Left': 0.12282919883728027,
#        'Top': 0.2117060273885727},
#       'Polygon': [{'X': 0.12282919883728027, 'Y': 0.21170827746391296},
#        {'X': 0.19568686187267303, 'Y': 0.2117060273885727},
#        {'X': 0.1956893354654312, 'Y': 0.2234376072883606},
#        {'X': 0.12283144146203995, 'Y': 0.22343973815441132}]},
#      'Id': '686a74ef-99fe-4e02-8e79-d60131db7ae1',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['1acd403a-05cc-441c-b7c5-bd3da6e3fe17']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 96.92146301269531,
#      'Text': 'On/Off',
#      'Geometry': {'BoundingBox': {'Width': 0.053892750293016434,
#        'Height': 0.012585548684000969,
#        'Left': 0.3149067461490631,
#        'Top': 0.21103134751319885},
#       'Polygon': [{'X': 0.3149067461490631, 'Y': 0.21103301644325256},
#        {'X': 0.3687962293624878, 'Y': 0.21103134751319885},
#        {'X': 0.36879950761795044, 'Y': 0.22361531853675842},
#        {'X': 0.31490981578826904, 'Y': 0.22361689805984497}]},
#      'Id': 'b135a502-aab0-4862-b0f4-52bf9fb7e8c1',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['6271cbb3-e1a4-4053-8dd4-d9a4469c2960']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 80.78031921386719,
#      'Text': 'On/ Off',
#      'Geometry': {'BoundingBox': {'Width': 0.054239898920059204,
#        'Height': 0.011757508851587772,
#        'Left': 0.506195604801178,
#        'Top': 0.2117171287536621},
#       'Polygon': [{'X': 0.506195604801178, 'Y': 0.21171881258487701},
#        {'X': 0.5604318380355835, 'Y': 0.2117171287536621},
#        {'X': 0.5604354739189148, 'Y': 0.22347305715084076},
#        {'X': 0.506199061870575, 'Y': 0.2234746366739273}]},
#      'Id': '3cd2a32f-af98-4f0b-b9db-49f7f779fa1c',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['29fe0d0d-3db7-4be0-833a-0f351eccfd5e',
#         '884c153b-4304-4365-acb4-9958480e1e81']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.33402252197266,
#      'Text': 'On/ Off',
#      'Geometry': {'BoundingBox': {'Width': 0.054288897663354874,
#        'Height': 0.011598791927099228,
#        'Left': 0.6969475150108337,
#        'Top': 0.21142101287841797},
#       'Polygon': [{'X': 0.6969475150108337, 'Y': 0.21142269670963287},
#        {'X': 0.7512322068214417, 'Y': 0.21142101287841797},
#        {'X': 0.7512363791465759, 'Y': 0.22301821410655975},
#        {'X': 0.6969515681266785, 'Y': 0.2230198085308075}]},
#      'Id': '90635fec-e2f8-4951-b494-de5e1da2879e',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['aa40a033-d443-4297-8a9e-ea28966fa193',
#         '0694a83c-926a-44ec-943c-568ed86a820e']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.93309783935547,
#      'Text': 'Run hours',
#      'Geometry': {'BoundingBox': {'Width': 0.07398056983947754,
#        'Height': 0.009822027757763863,
#        'Left': 0.12369467318058014,
#        'Top': 0.22759990394115448},
#       'Polygon': [{'X': 0.12369467318058014, 'Y': 0.227602019906044},
#        {'X': 0.19767315685749054, 'Y': 0.22759990394115448},
#        {'X': 0.19767524302005768, 'Y': 0.23741993308067322},
#        {'X': 0.12369654327630997, 'Y': 0.2374219447374344}]},
#      'Id': '51d5f63b-a5f3-48e3-96c7-c5e87d37ce2e',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['53b47792-3acc-47d1-8aee-a045ed800e66',
#         '84d29232-0c06-42a2-a216-ce0746248192']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.72441864013672,
#      'Text': 'Consumption',
#      'Geometry': {'BoundingBox': {'Width': 0.09813210368156433,
#        'Height': 0.011689168401062489,
#        'Left': 0.12307314574718475,
#        'Top': 0.24405616521835327},
#       'Polygon': [{'X': 0.12307314574718475, 'Y': 0.2440587282180786},
#        {'X': 0.22120270133018494, 'Y': 0.24405616521835327},
#        {'X': 0.22120524942874908, 'Y': 0.2557429075241089},
#        {'X': 0.12307538092136383, 'Y': 0.2557453215122223}]},
#      'Id': '1b35301c-ac36-4e4b-9f7b-584249e3cfb7',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['7d45f29f-44a0-4ce6-b533-6f89fc148af6']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.9483871459961,
#      'Text': 'Machine Run hours',
#      'Geometry': {'BoundingBox': {'Width': 0.14214375615119934,
#        'Height': 0.00962007511407137,
#        'Left': 0.12345993518829346,
#        'Top': 0.26001161336898804},
#       'Polygon': [{'X': 0.12345993518829346, 'Y': 0.2600150406360626},
#        {'X': 0.2656014859676361, 'Y': 0.26001161336898804},
#        {'X': 0.2656036913394928, 'Y': 0.26962849497795105},
#        {'X': 0.1234617680311203, 'Y': 0.2696317136287689}]},
#      'Id': '8694e261-5eb7-421e-922b-e6ec2ac3c072',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['e3e66802-a7f2-4593-9578-19b1338cf491',
#         '4016277f-a9d2-4e8b-bf91-147a1044a0ed',
#         '47151131-f5e8-47ec-8b72-8cadc943e2b7']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.4095230102539,
#      'Text': 'Value1',
#      'Geometry': {'BoundingBox': {'Width': 0.05033951252698898,
#        'Height': 0.00972252432256937,
#        'Left': 0.12237987667322159,
#        'Top': 0.27594640851020813},
#       'Polygon': [{'X': 0.12237987667322159, 'Y': 0.2759475111961365},
#        {'X': 0.1727174073457718, 'Y': 0.27594640851020813},
#        {'X': 0.17271938920021057, 'Y': 0.28566792607307434},
#        {'X': 0.12238173186779022, 'Y': 0.2856689393520355}]},
#      'Id': '0dd96240-1c52-4903-bc3c-0ba4b2dbed48',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['b81ec93a-beba-428a-91e3-9a34c1b3087f']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.86984252929688,
#      'Text': 'Value 2',
#      'Geometry': {'BoundingBox': {'Width': 0.05517628788948059,
#        'Height': 0.009788033552467823,
#        'Left': 0.12221693992614746,
#        'Top': 0.29192686080932617},
#       'Polygon': [{'X': 0.12221693992614746, 'Y': 0.29192790389060974},
#        {'X': 0.17739121615886688, 'Y': 0.29192686080932617},
#        {'X': 0.17739322781562805, 'Y': 0.30171388387680054},
#        {'X': 0.12221880257129669, 'Y': 0.30171486735343933}]},
#      'Id': '47982166-b769-4660-9e53-bca33396dd27',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['955d71f3-4512-44fc-ac38-6f2eb75e1c92',
#         'e5fd132e-6d1e-40f4-adbb-8d9623dc32cd']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.77840423583984,
#      'Text': 'Value3',
#      'Geometry': {'BoundingBox': {'Width': 0.05037067085504532,
#        'Height': 0.00995730608701706,
#        'Left': 0.12245579808950424,
#        'Top': 0.30773937702178955},
#       'Polygon': [{'X': 0.12245579808950424, 'Y': 0.3077402412891388},
#        {'X': 0.172824427485466, 'Y': 0.30773937702178955},
#        {'X': 0.17282646894454956, 'Y': 0.31769588589668274},
#        {'X': 0.12245769798755646, 'Y': 0.3176966607570648}]},
#      'Id': 'd6b92849-6942-4361-9bd0-8bcc9502274c',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['55428a09-0d50-4c07-816d-7d65be968beb']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.8968276977539,
#      'Text': 'Value4',
#      'Geometry': {'BoundingBox': {'Width': 0.05133598670363426,
#        'Height': 0.009865878149867058,
#        'Left': 0.12220058590173721,
#        'Top': 0.3238387107849121},
#       'Polygon': [{'X': 0.12220058590173721, 'Y': 0.3238394856452942},
#        {'X': 0.1735345423221588, 'Y': 0.3238387107849121},
#        {'X': 0.17353656888008118, 'Y': 0.3337039053440094},
#        {'X': 0.12220246344804764, 'Y': 0.3337045907974243}]},
#      'Id': '5ee0e0fd-b48a-46d6-85c5-48c5df543ae8',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['40c9b4e4-3202-4a7d-9c52-c80e400995d3']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 61.5478401184082,
#      'Text': '{',
#      'Geometry': {'BoundingBox': {'Width': 0.06648002564907074,
#        'Height': 0.12935934960842133,
#        'Left': 0.713908314704895,
#        'Top': 0.2364359200000763},
#       'Polygon': [{'X': 0.713908314704895, 'Y': 0.23643773794174194},
#        {'X': 0.7803401947021484, 'Y': 0.2364359200000763},
#        {'X': 0.780388355255127, 'Y': 0.36579468846321106},
#        {'X': 0.7139540910720825, 'Y': 0.3657952547073364}]},
#      'Id': '67a89d60-be7c-42fb-8957-68822db227be',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['94fb6b96-d968-4d53-b011-883c04eb7a9d']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.80653381347656,
#      'Text': 'Value5',
#      'Geometry': {'BoundingBox': {'Width': 0.05075633525848389,
#        'Height': 0.009880410507321358,
#        'Left': 0.1222001314163208,
#        'Top': 0.3399735689163208},
#       'Polygon': [{'X': 0.1222001314163208, 'Y': 0.33997419476509094},
#        {'X': 0.17295444011688232, 'Y': 0.3399735689163208},
#        {'X': 0.1729564666748047, 'Y': 0.34985342621803284},
#        {'X': 0.12220201641321182, 'Y': 0.3498539924621582}]},
#      'Id': '56c698a0-204c-46dd-9311-fb414ab1054a',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['11410212-1454-42be-89ff-e573db84748c']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.85883331298828,
#      'Text': 'Value6',
#      'Geometry': {'BoundingBox': {'Width': 0.0513094924390316,
#        'Height': 0.009858204051852226,
#        'Left': 0.12210270017385483,
#        'Top': 0.35612618923187256},
#       'Polygon': [{'X': 0.12210270017385483, 'Y': 0.35612672567367554},
#        {'X': 0.17341017723083496, 'Y': 0.35612618923187256},
#        {'X': 0.17341218888759613, 'Y': 0.3659839630126953},
#        {'X': 0.12210457772016525, 'Y': 0.36598441004753113}]},
#      'Id': 'cf28edfe-0461-46c6-a0c9-3e20703e57e4',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['b8427445-8a1f-4070-992c-2b4f9930e02d']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.75251007080078,
#      'Text': 'System#2',
#      'Geometry': {'BoundingBox': {'Width': 0.07271420210599899,
#        'Height': 0.011514698155224323,
#        'Left': 0.12249376624822617,
#        'Top': 0.3723590672016144},
#       'Polygon': [{'X': 0.12249376624822617, 'Y': 0.37235963344573975},
#        {'X': 0.19520553946495056, 'Y': 0.3723590672016144},
#        {'X': 0.19520796835422516, 'Y': 0.38387331366539},
#        {'X': 0.12249596416950226, 'Y': 0.38387376070022583}]},
#      'Id': 'e1cfcb99-8a52-40cc-abb8-8ef6b2e306e4',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['60ae461e-5cd7-40ea-becd-e8a8e206d3b3']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 86.92597961425781,
#      'Text': 'On/Off',
#      'Geometry': {'BoundingBox': {'Width': 0.05445219576358795,
#        'Height': 0.011328778229653835,
#        'Left': 0.312785267829895,
#        'Top': 0.3719377815723419},
#       'Polygon': [{'X': 0.312785267829895, 'Y': 0.37193822860717773},
#        {'X': 0.3672345280647278, 'Y': 0.3719377815723419},
#        {'X': 0.3672374486923218, 'Y': 0.38326624035835266},
#        {'X': 0.3127880096435547, 'Y': 0.3832665681838989}]},
#      'Id': 'ce1bf7aa-77bf-4133-8c33-3cd2eba5b0ef',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['f4cff25b-5da4-494e-9b01-5956e57c29f2']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 89.53392028808594,
#      'Text': 'On/Off',
#      'Geometry': {'BoundingBox': {'Width': 0.051999807357788086,
#        'Height': 0.011001081205904484,
#        'Left': 0.5061017870903015,
#        'Top': 0.37175843119621277},
#       'Polygon': [{'X': 0.5061017870903015, 'Y': 0.3717588186264038},
#        {'X': 0.5580981373786926, 'Y': 0.37175843119621277},
#        {'X': 0.5581015944480896, 'Y': 0.3827591836452484},
#        {'X': 0.5061050057411194, 'Y': 0.3827595114707947}]},
#      'Id': 'c175051c-ba03-43e5-8763-60a7da08a78c',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['67b5cd40-9045-4f06-9e43-80a5e2152248']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 85.08697509765625,
#      'Text': 'On/Off',
#      'Geometry': {'BoundingBox': {'Width': 0.054274361580610275,
#        'Height': 0.011466781608760357,
#        'Left': 0.6964499950408936,
#        'Top': 0.3720282316207886},
#       'Polygon': [{'X': 0.6964499950408936, 'Y': 0.3720286786556244},
#        {'X': 0.7507201433181763, 'Y': 0.3720282316207886},
#        {'X': 0.7507243156433105, 'Y': 0.38349470496177673},
#        {'X': 0.6964539885520935, 'Y': 0.383495032787323}]},
#      'Id': 'faffa067-171b-420b-b644-43ae40dc5ba2',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['28b16f9e-de30-4d2e-b9cb-69313fd711d3']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.94652557373047,
#      'Text': 'Run hours',
#      'Geometry': {'BoundingBox': {'Width': 0.07400254905223846,
#        'Height': 0.00970807671546936,
#        'Left': 0.12348189204931259,
#        'Top': 0.388447105884552},
#       'Polygon': [{'X': 0.12348189204931259, 'Y': 0.38844749331474304},
#        {'X': 0.1974823772907257, 'Y': 0.388447105884552},
#        {'X': 0.19748443365097046, 'Y': 0.3981548845767975},
#        {'X': 0.12348374724388123, 'Y': 0.39815518260002136}]},
#      'Id': 'bbce4014-0dab-46e7-8d02-f83c3d0541a8',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['327f145a-e9db-407a-bcd5-2b85d80c1ed2',
#         'cfc4b66a-4b68-4013-b41b-0a1d7b97cec4']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.6749496459961,
#      'Text': '4365',
#      'Geometry': {'BoundingBox': {'Width': 0.05722229927778244,
#        'Height': 0.01344145368784666,
#        'Left': 0.3257700204849243,
#        'Top': 0.38991066813468933},
#       'Polygon': [{'X': 0.3257700204849243, 'Y': 0.3899109661579132},
#        {'X': 0.3829888105392456, 'Y': 0.38991066813468933},
#        {'X': 0.38299232721328735, 'Y': 0.40335193276405334},
#        {'X': 0.32577335834503174, 'Y': 0.40335214138031006}]},
#      'Id': '0b67b69f-d529-4a8a-88fb-84c61aed2f7e',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['2bd7ea29-e17c-4927-8cd5-dc390f7c2171']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.8175048828125,
#      'Text': '2342',
#      'Geometry': {'BoundingBox': {'Width': 0.07689227163791656,
#        'Height': 0.014441507868468761,
#        'Left': 0.5151378512382507,
#        'Top': 0.38880667090415955},
#       'Polygon': [{'X': 0.5151378512382507, 'Y': 0.388807088136673},
#        {'X': 0.5920254588127136, 'Y': 0.38880667090415955},
#        {'X': 0.5920301079750061, 'Y': 0.4032479226589203},
#        {'X': 0.5151421427726746, 'Y': 0.4032481908798218}]},
#      'Id': '33d0e593-bc9a-49f2-844b-b97bb4ba96b2',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['2709103b-7c13-4232-89b8-1e7f88b4474c']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.94467163085938,
#      'Text': '3437',
#      'Geometry': {'BoundingBox': {'Width': 0.06691861897706985,
#        'Height': 0.01433796901255846,
#        'Left': 0.7049760818481445,
#        'Top': 0.3881693482398987},
#       'Polygon': [{'X': 0.7049760818481445, 'Y': 0.3881697356700897},
#        {'X': 0.7718893885612488, 'Y': 0.3881693482398987},
#        {'X': 0.7718946933746338, 'Y': 0.40250709652900696},
#        {'X': 0.7049811482429504, 'Y': 0.40250733494758606}]},
#      'Id': 'e567fd7e-3bd3-498f-a5f9-748da87654f3',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['667e87fa-f710-41ef-abf5-4717f9026fe1']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.82882690429688,
#      'Text': 'Consumption',
#      'Geometry': {'BoundingBox': {'Width': 0.09820762276649475,
#        'Height': 0.011584611609578133,
#        'Left': 0.12269125133752823,
#        'Top': 0.4048406481742859},
#       'Polygon': [{'X': 0.12269125133752823, 'Y': 0.40484094619750977},
#        {'X': 0.22089634835720062, 'Y': 0.4048406481742859},
#        {'X': 0.22089888155460358, 'Y': 0.4164251387119293},
#        {'X': 0.12269345670938492, 'Y': 0.41642525792121887}]},
#      'Id': '21e231d4-3ef8-4368-8c1e-b7b3820a8075',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['18d09865-0c0e-46be-9909-675443bfc5c1']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.96682739257812,
#      'Text': '5766229',
#      'Geometry': {'BoundingBox': {'Width': 0.1123690977692604,
#        'Height': 0.01795075088739395,
#        'Left': 0.32770660519599915,
#        'Top': 0.40385282039642334},
#       'Polygon': [{'X': 0.32770660519599915, 'Y': 0.403853178024292},
#        {'X': 0.4400706887245178, 'Y': 0.40385282039642334},
#        {'X': 0.44007569551467896, 'Y': 0.4218035042285919},
#        {'X': 0.3277110457420349, 'Y': 0.4218035638332367}]},
#      'Id': '34a1ea93-2518-4b73-b9dc-9b9d1df3aca7',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['ab967779-3096-4a5c-b1c4-4ebcc750f641']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.20721435546875,
#      'Text': '7332114',
#      'Geometry': {'BoundingBox': {'Width': 0.09977835416793823,
#        'Height': 0.017901815474033356,
#        'Left': 0.5148820877075195,
#        'Top': 0.4042806327342987},
#       'Polygon': [{'X': 0.5148820877075195, 'Y': 0.40428096055984497},
#        {'X': 0.6146546006202698, 'Y': 0.4042806327342987},
#        {'X': 0.6146605014801025, 'Y': 0.4221823811531067},
#        {'X': 0.5148874521255493, 'Y': 0.42218244075775146}]},
#      'Id': 'c22e41c3-a90b-4f45-bf45-c6d4903fe32c',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['74e43afb-060e-4f3d-8364-1066e9256f49']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.91107940673828,
#      'Text': '6944572',
#      'Geometry': {'BoundingBox': {'Width': 0.11860676854848862,
#        'Height': 0.01645117625594139,
#        'Left': 0.7143989205360413,
#        'Top': 0.40440401434898376},
#       'Polygon': [{'X': 0.7143989205360413, 'Y': 0.4044043719768524},
#        {'X': 0.8329993486404419, 'Y': 0.40440401434898376},
#        {'X': 0.8330056667327881, 'Y': 0.4208550751209259},
#        {'X': 0.7144047617912292, 'Y': 0.42085519433021545}]},
#      'Id': 'bfd10c74-a986-44ab-87cc-afb816d58387',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['9bf8d61f-9443-435a-9476-f2bfbdacfb4c']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.91033935546875,
#      'Text': 'Machine Run hours',
#      'Geometry': {'BoundingBox': {'Width': 0.14210744202136993,
#        'Height': 0.009912578389048576,
#        'Left': 0.12302684783935547,
#        'Top': 0.420747309923172},
#       'Polygon': [{'X': 0.12302684783935547, 'Y': 0.42074742913246155},
#        {'X': 0.26513200998306274, 'Y': 0.420747309923172},
#        {'X': 0.2651343047618866, 'Y': 0.4306598901748657},
#        {'X': 0.12302874028682709, 'Y': 0.43065980076789856}]},
#      'Id': 'b8eaf0ab-8d51-453f-92ef-16a4fdb3c051',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['69dd8b18-748e-4b27-9007-112393bc10d9',
#         '6e95c02e-542d-4234-8a01-5dbfc5a32612',
#         'db7c4b71-d516-4287-856e-fdf23cb16613']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.95484161376953,
#      'Text': '21',
#      'Geometry': {'BoundingBox': {'Width': 0.03297518566250801,
#        'Height': 0.01062540803104639,
#        'Left': 0.34942495822906494,
#        'Top': 0.42244821786880493},
#       'Polygon': [{'X': 0.34942495822906494, 'Y': 0.42244821786880493},
#        {'X': 0.3823973536491394, 'Y': 0.42244821786880493},
#        {'X': 0.38240015506744385, 'Y': 0.43307361006736755},
#        {'X': 0.3494276702404022, 'Y': 0.43307358026504517}]},
#      'Id': 'f630c3a2-4081-4414-8a7a-556aa1683369',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['b9d2788c-ff15-4422-a85d-fa401120b564']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.51819610595703,
#      'Text': '21',
#      'Geometry': {'BoundingBox': {'Width': 0.03366520628333092,
#        'Height': 0.01171514019370079,
#        'Left': 0.5398130416870117,
#        'Top': 0.42204388976097107},
#       'Polygon': [{'X': 0.5398130416870117, 'Y': 0.42204391956329346},
#        {'X': 0.5734745264053345, 'Y': 0.42204388976097107},
#        {'X': 0.5734782218933105, 'Y': 0.43375903367996216},
#        {'X': 0.5398166179656982, 'Y': 0.43375900387763977}]},
#      'Id': 'b84bd54d-6e4b-4df0-b26a-30cb713801e1',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['131a7404-97d4-45f5-83cf-44de07bbd669']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.67359161376953,
#      'Text': '21',
#      'Geometry': {'BoundingBox': {'Width': 0.034274060279130936,
#        'Height': 0.011748507618904114,
#        'Left': 0.7281045317649841,
#        'Top': 0.42122629284858704},
#       'Polygon': [{'X': 0.7281045317649841, 'Y': 0.4212263226509094},
#        {'X': 0.7623742818832397, 'Y': 0.42122629284858704},
#        {'X': 0.7623785734176636, 'Y': 0.43297481536865234},
#        {'X': 0.7281087040901184, 'Y': 0.43297478556632996}]},
#      'Id': '74fa10fe-03ce-46cd-becf-496a0d0efdd4',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['a026ad1f-b9e1-437b-bf3c-fbc43d39b4d6']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.44221496582031,
#      'Text': 'Value1',
#      'Geometry': {'BoundingBox': {'Width': 0.0500943548977375,
#        'Height': 0.009866408072412014,
#        'Left': 0.12201239168643951,
#        'Top': 0.43662750720977783},
#       'Polygon': [{'X': 0.12201239168643951, 'Y': 0.43662750720977783},
#        {'X': 0.17210473120212555, 'Y': 0.4366275668144226},
#        {'X': 0.17210674285888672, 'Y': 0.446493923664093},
#        {'X': 0.12201426923274994, 'Y': 0.4464937746524811}]},
#      'Id': '5508e1a6-add4-402b-935f-fe95027804ff',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['790c49b5-15f1-4e94-b2a6-2d28038214ee']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 69.38408660888672,
#      'Text': '12',
#      'Geometry': {'BoundingBox': {'Width': 0.03191734477877617,
#        'Height': 0.010312655940651894,
#        'Left': 0.35772472620010376,
#        'Top': 0.43708300590515137},
#       'Polygon': [{'X': 0.35772472620010376, 'Y': 0.43708300590515137},
#        {'X': 0.38963934779167175, 'Y': 0.43708306550979614},
#        {'X': 0.38964205980300903, 'Y': 0.4473956525325775},
#        {'X': 0.3577273488044739, 'Y': 0.44739556312561035}]},
#      'Id': '8558993f-1ec1-4ea0-9542-8fd443d1e2a4',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['6e8dc3ec-5775-43dd-896b-ccc1250ac72a']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 87.72600555419922,
#      'Text': '72',
#      'Geometry': {'BoundingBox': {'Width': 0.042908333241939545,
#        'Height': 0.01400578673928976,
#        'Left': 0.5381590723991394,
#        'Top': 0.4361613094806671},
#       'Polygon': [{'X': 0.5381590723991394, 'Y': 0.4361613094806671},
#        {'X': 0.5810629725456238, 'Y': 0.4361613690853119},
#        {'X': 0.5810674428939819, 'Y': 0.45016708970069885},
#        {'X': 0.5381633639335632, 'Y': 0.4501669406890869}]},
#      'Id': '03995ac8-4771-46b5-b652-1926db539a84',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['f14b6cf1-0eb9-4e37-bd77-c08f2b47072e']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 65.22988891601562,
#      'Text': '8 1',
#      'Geometry': {'BoundingBox': {'Width': 0.029840530827641487,
#        'Height': 0.011421045288443565,
#        'Left': 0.7323862910270691,
#        'Top': 0.4370725750923157},
#       'Polygon': [{'X': 0.7323862910270691, 'Y': 0.4370725750923157},
#        {'X': 0.7622226476669312, 'Y': 0.43707263469696045},
#        {'X': 0.7622268199920654, 'Y': 0.448493629693985},
#        {'X': 0.7323904037475586, 'Y': 0.4484935402870178}]},
#      'Id': '9de85ee4-9071-4304-9f3d-78099a7de964',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['3c04044f-a1a7-4d6b-b389-10c401398971']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.8947982788086,
#      'Text': 'Value 2',
#      'Geometry': {'BoundingBox': {'Width': 0.05464767664670944,
#        'Height': 0.00955057330429554,
#        'Left': 0.12211666256189346,
#        'Top': 0.45301708579063416},
#       'Polygon': [{'X': 0.12211666256189346, 'Y': 0.45301708579063416},
#        {'X': 0.17676237225532532, 'Y': 0.45301729440689087},
#        {'X': 0.1767643392086029, 'Y': 0.46256765723228455},
#        {'X': 0.12211848050355911, 'Y': 0.46256735920906067}]},
#      'Id': 'b21eaa08-0eac-4c72-b6ec-965836fd0d68',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['80219e2c-fa8c-4560-a3cb-87e0ec1d3cf2',
#         '0baa0879-80cc-4ebf-b92c-82a18a65e6a4']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 89.987060546875,
#      'Text': '31',
#      'Geometry': {'BoundingBox': {'Width': 0.035904254764318466,
#        'Height': 0.012345096096396446,
#        'Left': 0.361145555973053,
#        'Top': 0.4532015323638916},
#       'Polygon': [{'X': 0.361145555973053, 'Y': 0.4532015323638916},
#        {'X': 0.3970465362071991, 'Y': 0.45320165157318115},
#        {'X': 0.39704981446266174, 'Y': 0.4655466079711914},
#        {'X': 0.3611487150192261, 'Y': 0.4655464291572571}]},
#      'Id': '78a47654-6b4a-4252-9fa3-5ed091c7d180',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['be91a0b8-abc5-4769-a72a-56b6876b4cbc']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 87.71835327148438,
#      'Text': '13',
#      'Geometry': {'BoundingBox': {'Width': 0.03766678646206856,
#        'Height': 0.010760215111076832,
#        'Left': 0.5419060587882996,
#        'Top': 0.4543006420135498},
#       'Polygon': [{'X': 0.5419060587882996, 'Y': 0.4543006420135498},
#        {'X': 0.5795694589614868, 'Y': 0.45430079102516174},
#        {'X': 0.579572856426239, 'Y': 0.465060830116272},
#        {'X': 0.5419093370437622, 'Y': 0.46506062150001526}]},
#      'Id': '3d19f741-eaa1-400e-90b2-88a1110371af',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['f4c766ad-c195-42ba-a358-66f3f5ef407c']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 86.94224548339844,
#      'Text': '73',
#      'Geometry': {'BoundingBox': {'Width': 0.04240599274635315,
#        'Height': 0.013281608931720257,
#        'Left': 0.7274212837219238,
#        'Top': 0.4534485638141632},
#       'Polygon': [{'X': 0.7274212837219238, 'Y': 0.4534485638141632},
#        {'X': 0.769822359085083, 'Y': 0.45344871282577515},
#        {'X': 0.7698273062705994, 'Y': 0.46673017740249634},
#        {'X': 0.7274260520935059, 'Y': 0.46672993898391724}]},
#      'Id': '09cf7600-98ec-4528-9aa9-f215c02299b9',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['36ab2f02-35bf-4a94-8fcd-dc58054ef5c8']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.89852142333984,
#      'Text': 'Value3',
#      'Geometry': {'BoundingBox': {'Width': 0.05024499073624611,
#        'Height': 0.009965116158127785,
#        'Left': 0.1222240999341011,
#        'Top': 0.46877455711364746},
#       'Polygon': [{'X': 0.1222240999341011, 'Y': 0.46877455711364746},
#        {'X': 0.17246705293655396, 'Y': 0.46877485513687134},
#        {'X': 0.1724690943956375, 'Y': 0.4787396490573883},
#        {'X': 0.12222599983215332, 'Y': 0.47873929142951965}]},
#      'Id': 'b9a43c33-c736-48dc-b23c-f265ab635e07',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['64522de9-e7e7-478d-b4eb-1d9bd18f9130']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 58.52708053588867,
#      'Text': '5 1',
#      'Geometry': {'BoundingBox': {'Width': 0.03718310967087746,
#        'Height': 0.012054430320858955,
#        'Left': 0.3613355755805969,
#        'Top': 0.47040995955467224},
#       'Polygon': [{'X': 0.3613355755805969, 'Y': 0.47040995955467224},
#        {'X': 0.3985154628753662, 'Y': 0.47041016817092896},
#        {'X': 0.3985186815261841, 'Y': 0.48246437311172485},
#        {'X': 0.36133867502212524, 'Y': 0.482464075088501}]},
#      'Id': '474da77e-df58-4599-b926-dac9ac8f7faa',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['7a523178-3836-4dad-bdca-cea0959e6b9f']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 97.17180633544922,
#      'Text': '21',
#      'Geometry': {'BoundingBox': {'Width': 0.03234270587563515,
#        'Height': 0.011977001093327999,
#        'Left': 0.5433446764945984,
#        'Top': 0.4707235097885132},
#       'Polygon': [{'X': 0.5433446764945984, 'Y': 0.4707235097885132},
#        {'X': 0.57568359375, 'Y': 0.4707237184047699},
#        {'X': 0.5756874084472656, 'Y': 0.48270052671432495},
#        {'X': 0.5433483719825745, 'Y': 0.48270025849342346}]},
#      'Id': 'b5a6bf0f-d64d-4c1f-b2aa-3d92ad67caf3',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['9fedda84-5cee-490d-a44d-6ee10ecab326']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 89.0531005859375,
#      'Text': '55',
#      'Geometry': {'BoundingBox': {'Width': 0.035715389996767044,
#        'Height': 0.0121883824467659,
#        'Left': 0.7312830090522766,
#        'Top': 0.47077062726020813},
#       'Polygon': [{'X': 0.7312830090522766, 'Y': 0.47077062726020813},
#        {'X': 0.7669939398765564, 'Y': 0.47077086567878723},
#        {'X': 0.7669984102249146, 'Y': 0.48295900225639343},
#        {'X': 0.73128741979599, 'Y': 0.48295873403549194}]},
#      'Id': 'ed5dfe08-7e88-4a61-8ff3-4afd2d994030',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['fd3b2323-4f6f-4956-aa17-c4d90aa65018']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.91380310058594,
#      'Text': 'Value4',
#      'Geometry': {'BoundingBox': {'Width': 0.05117857828736305,
#        'Height': 0.00968776736408472,
#        'Left': 0.12183820456266403,
#        'Top': 0.4850160777568817},
#       'Polygon': [{'X': 0.12183820456266403, 'Y': 0.4850160777568817},
#        {'X': 0.1730148047208786, 'Y': 0.48501652479171753},
#        {'X': 0.17301678657531738, 'Y': 0.49470385909080505},
#        {'X': 0.12184004485607147, 'Y': 0.49470335245132446}]},
#      'Id': '2d22b62c-576e-4d5e-8034-81986e291a4f',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['201148ec-a3a4-4d13-b202-33674d44cda8']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.61103057861328,
#      'Text': '79',
#      'Geometry': {'BoundingBox': {'Width': 0.03391224145889282,
#        'Height': 0.014715147204697132,
#        'Left': 0.362167090177536,
#        'Top': 0.48434898257255554},
#       'Polygon': [{'X': 0.362167090177536, 'Y': 0.48434898257255554},
#        {'X': 0.39607542753219604, 'Y': 0.4843492805957794},
#        {'X': 0.39607933163642883, 'Y': 0.4990641474723816},
#        {'X': 0.36217087507247925, 'Y': 0.49906378984451294}]},
#      'Id': 'd537b3f7-d073-4ec8-9892-19b5988284ff',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['a0398d3a-eaa7-4f3c-88bd-32674041b5d1']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 98.44941711425781,
#      'Text': '51',
#      'Geometry': {'BoundingBox': {'Width': 0.025870181620121002,
#        'Height': 0.01251301635056734,
#        'Left': 0.5462856888771057,
#        'Top': 0.4856787621974945},
#       'Polygon': [{'X': 0.5462856888771057, 'Y': 0.4856787621974945},
#        {'X': 0.5721518993377686, 'Y': 0.4856790006160736},
#        {'X': 0.5721558332443237, 'Y': 0.49819180369377136},
#        {'X': 0.5462895035743713, 'Y': 0.4981915354728699}]},
#      'Id': '62b726b2-e46b-4557-aa3a-d1eb35429113',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['9a841785-4a1c-4d80-84aa-cc7a1795df68']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.93317413330078,
#      'Text': '19',
#      'Geometry': {'BoundingBox': {'Width': 0.030088534578680992,
#        'Height': 0.012790448032319546,
#        'Left': 0.7317273020744324,
#        'Top': 0.48528116941452026},
#       'Polygon': [{'X': 0.7317273020744324, 'Y': 0.48528116941452026},
#        {'X': 0.7618111371994019, 'Y': 0.48528143763542175},
#        {'X': 0.7618158459663391, 'Y': 0.4980716109275818},
#        {'X': 0.7317318916320801, 'Y': 0.4980713129043579}]},
#      'Id': 'f04cbb5b-e7fb-491d-a7f5-34336de6dd13',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['a10fa1a0-8070-4546-81cb-1c27e7998b1b']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.73118591308594,
#      'Text': 'Value5',
#      'Geometry': {'BoundingBox': {'Width': 0.05069199204444885,
#        'Height': 0.010080238804221153,
#        'Left': 0.12194593250751495,
#        'Top': 0.5010472536087036},
#       'Polygon': [{'X': 0.12194593250751495, 'Y': 0.5010472536087036},
#        {'X': 0.17263586819171906, 'Y': 0.5010478496551514},
#        {'X': 0.1726379245519638, 'Y': 0.5111275315284729},
#        {'X': 0.12194785475730896, 'Y': 0.5111268758773804}]},
#      'Id': '7a9f7a8c-4adc-4c7b-b540-ef0e789a3de7',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['fbb003d1-72c4-41fb-ba8d-b5a27882b24e']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 90.23904418945312,
#      'Text': '62',
#      'Geometry': {'BoundingBox': {'Width': 0.048693981021642685,
#        'Height': 0.011669819243252277,
#        'Left': 0.36023494601249695,
#        'Top': 0.5012640357017517},
#       'Polygon': [{'X': 0.36023494601249695, 'Y': 0.5012640357017517},
#        {'X': 0.4089258015155792, 'Y': 0.5012645721435547},
#        {'X': 0.40892893075942993, 'Y': 0.5129338502883911},
#        {'X': 0.3602379560470581, 'Y': 0.5129332542419434}]},
#      'Id': '2e9a01ef-13a6-4200-95cd-3c122ab16dc2',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['4b372a4f-652b-4c16-80a3-c4381a0493f8']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 88.47735595703125,
#      'Text': '48',
#      'Geometry': {'BoundingBox': {'Width': 0.035460423678159714,
#        'Height': 0.014177068136632442,
#        'Left': 0.5459315776824951,
#        'Top': 0.5023927688598633},
#       'Polygon': [{'X': 0.5459315776824951, 'Y': 0.5023927688598633},
#        {'X': 0.5813875198364258, 'Y': 0.5023931264877319},
#        {'X': 0.5813919901847839, 'Y': 0.5165698528289795},
#        {'X': 0.5459359288215637, 'Y': 0.5165693759918213}]},
#      'Id': '1c418956-ffe3-4e4b-ab1b-03ae61a86ba0',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['eed27da9-e797-4203-a336-039be66687fb']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 65.22335815429688,
#      'Text': '18',
#      'Geometry': {'BoundingBox': {'Width': 0.03716425597667694,
#        'Height': 0.014006225392222404,
#        'Left': 0.7289549112319946,
#        'Top': 0.501013994216919},
#       'Polygon': [{'X': 0.7289549112319946, 'Y': 0.501013994216919},
#        {'X': 0.7661139965057373, 'Y': 0.5010144114494324},
#        {'X': 0.7661191821098328, 'Y': 0.5150202512741089},
#        {'X': 0.7289599180221558, 'Y': 0.5150197744369507}]},
#      'Id': 'c7930a2e-588f-4c3b-bc1f-788ffe8bcfce',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['65204616-c2a6-45d8-bd6f-2e5f736a7343']}],
#      'Page': 1},
#     {'BlockType': 'LINE',
#      'Confidence': 99.7684097290039,
# ...
#        {'X': 0.4970027506351471, 'Y': 0.6115064024925232},
#        {'X': 0.30536922812461853, 'Y': 0.6114718317985535}]},
#      'Id': '7c35a6f1-3828-4475-9858-6e42ebed35af',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 89.74609375,
#      'RowIndex': 5,
#      'ColumnIndex': 3,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19069920480251312,
#        'Height': 0.016043467447161674,
#        'Left': 0.49700018763542175,
#        'Top': 0.5954973101615906},
#       'Polygon': [{'X': 0.49700018763542175, 'Y': 0.5954973101615906},
#        {'X': 0.6876958608627319, 'Y': 0.5955314040184021},
#        {'X': 0.6876993775367737, 'Y': 0.6115407943725586},
#        {'X': 0.4970027506351471, 'Y': 0.6115064024925232}]},
#      'Id': 'be803647-5563-417c-aaf3-4b55164a140d',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.623046875,
#      'RowIndex': 5,
#      'ColumnIndex': 4,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19162778556346893,
#        'Height': 0.016043933108448982,
#        'Left': 0.6876958608627319,
#        'Top': 0.5955314040184021},
#       'Polygon': [{'X': 0.6876958608627319, 'Y': 0.5955314040184021},
#        {'X': 0.8793191909790039, 'Y': 0.595565676689148},
#        {'X': 0.8793236613273621, 'Y': 0.6115753650665283},
#        {'X': 0.6876993775367737, 'Y': 0.6115407943725586}]},
#      'Id': 'b086bd8a-35ce-4256-b650-1466689c6ea8',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.720703125,
#      'RowIndex': 6,
#      'ColumnIndex': 1,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19155718386173248,
#        'Height': 0.016377002000808716,
#        'Left': 0.11381369084119797,
#        'Top': 0.6114372611045837},
#       'Polygon': [{'X': 0.11381369084119797, 'Y': 0.6114372611045837},
#        {'X': 0.30536922812461853, 'Y': 0.6114718317985535},
#        {'X': 0.30537086725234985, 'Y': 0.6278142929077148},
#        {'X': 0.11381436139345169, 'Y': 0.6277794241905212}]},
#      'Id': 'ebb44010-8c5d-4431-b859-5f94c684d311',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['4ad754d9-b02d-4929-bdd2-a05743a82dc2',
#         'f4b3d490-0ca7-4f9e-b0f2-aaf3f6834ffb']}],
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.98828125,
#      'RowIndex': 6,
#      'ColumnIndex': 2,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1916361302137375,
#        'Height': 0.016377322375774384,
#        'Left': 0.30536922812461853,
#        'Top': 0.6114718317985535},
#       'Polygon': [{'X': 0.30536922812461853, 'Y': 0.6114718317985535},
#        {'X': 0.4970027506351471, 'Y': 0.6115064024925232},
#        {'X': 0.4970053732395172, 'Y': 0.6278491616249084},
#        {'X': 0.30537086725234985, 'Y': 0.6278142929077148}]},
#      'Id': '9e9a7a42-7aae-4ce7-b80c-62ef2aa28382',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.37890625,
#      'RowIndex': 6,
#      'ColumnIndex': 3,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1907002180814743,
#        'Height': 0.016377458348870277,
#        'Left': 0.4970027506351471,
#        'Top': 0.6115064024925232},
#       'Polygon': [{'X': 0.4970027506351471, 'Y': 0.6115064024925232},
#        {'X': 0.6876993775367737, 'Y': 0.6115407943725586},
#        {'X': 0.6877029538154602, 'Y': 0.6278838515281677},
#        {'X': 0.4970053732395172, 'Y': 0.6278491616249084}]},
#      'Id': '9c397793-46f0-4560-9b40-7246cbff0d23',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.255859375,
#      'RowIndex': 6,
#      'ColumnIndex': 4,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1916288286447525,
#        'Height': 0.016377931460738182,
#        'Left': 0.6876993775367737,
#        'Top': 0.6115407943725586},
#       'Polygon': [{'X': 0.6876993775367737, 'Y': 0.6115407943725586},
#        {'X': 0.8793236613273621, 'Y': 0.6115753650665283},
#        {'X': 0.8793282508850098, 'Y': 0.6279187202453613},
#        {'X': 0.6877029538154602, 'Y': 0.6278838515281677}]},
#      'Id': '957701e3-ccd6-43c0-bcde-0319818b0f7d',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.98828125,
#      'RowIndex': 7,
#      'ColumnIndex': 1,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1915581226348877,
#        'Height': 0.016043948009610176,
#        'Left': 0.11381436139345169,
#        'Top': 0.6277794241905212},
#       'Polygon': [{'X': 0.11381436139345169, 'Y': 0.6277794241905212},
#        {'X': 0.30537086725234985, 'Y': 0.6278142929077148},
#        {'X': 0.3053724765777588, 'Y': 0.6438233852386475},
#        {'X': 0.11381502449512482, 'Y': 0.64378821849823}]},
#      'Id': '9956ffe8-2c89-400f-a58b-bbb09db9151e',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['0b68d0b2-7897-41a4-b88e-19a64009a4b3']}],
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.255859375,
#      'RowIndex': 7,
#      'ColumnIndex': 2,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1916370540857315,
#        'Height': 0.016044262796640396,
#        'Left': 0.30537086725234985,
#        'Top': 0.6278142929077148},
#       'Polygon': [{'X': 0.30537086725234985, 'Y': 0.6278142929077148},
#        {'X': 0.4970053732395172, 'Y': 0.6278491616249084},
#        {'X': 0.49700793623924255, 'Y': 0.6438585519790649},
#        {'X': 0.3053724765777588, 'Y': 0.6438233852386475}]},
#      'Id': '7a2731ff-c6f4-4274-947b-7e89b59df06f',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.59765625,
#      'RowIndex': 7,
#      'ColumnIndex': 3,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19070111215114594,
#        'Height': 0.016044391319155693,
#        'Left': 0.4970053732395172,
#        'Top': 0.6278491616249084},
#       'Polygon': [{'X': 0.4970053732395172, 'Y': 0.6278491616249084},
#        {'X': 0.6877029538154602, 'Y': 0.6278838515281677},
#        {'X': 0.687706470489502, 'Y': 0.6438935399055481},
#        {'X': 0.49700793623924255, 'Y': 0.6438585519790649}]},
#      'Id': 'e5be004a-1bb5-424a-b92f-d314a467e1d4',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 86.474609375,
#      'RowIndex': 7,
#      'ColumnIndex': 4,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19162970781326294,
#        'Height': 0.0160448607057333,
#        'Left': 0.6877029538154602,
#        'Top': 0.6278838515281677},
#       'Polygon': [{'X': 0.6877029538154602, 'Y': 0.6278838515281677},
#        {'X': 0.8793282508850098, 'Y': 0.6279187202453613},
#        {'X': 0.8793326616287231, 'Y': 0.6439287066459656},
#        {'X': 0.687706470489502, 'Y': 0.6438935399055481}]},
#      'Id': 'a767e905-8148-4afa-a2da-0867607868ff',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.720703125,
#      'RowIndex': 8,
#      'ColumnIndex': 1,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1915590763092041,
#        'Height': 0.016044406220316887,
#        'Left': 0.11381502449512482,
#        'Top': 0.64378821849823},
#       'Polygon': [{'X': 0.11381502449512482, 'Y': 0.64378821849823},
#        {'X': 0.3053724765777588, 'Y': 0.6438233852386475},
#        {'X': 0.3053740859031677, 'Y': 0.6598325967788696},
#        {'X': 0.11381568759679794, 'Y': 0.6597971320152283}]},
#      'Id': '1f44e397-d4e2-4436-80e4-c1a7320bf324',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['9608591b-1ee4-4fe2-8f5b-b51ea1fa7e54']}],
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.98828125,
#      'RowIndex': 8,
#      'ColumnIndex': 2,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1916380077600479,
#        'Height': 0.016044721007347107,
#        'Left': 0.3053724765777588,
#        'Top': 0.6438233852386475},
#       'Polygon': [{'X': 0.3053724765777588, 'Y': 0.6438233852386475},
#        {'X': 0.49700793623924255, 'Y': 0.6438585519790649},
#        {'X': 0.4970104992389679, 'Y': 0.659868061542511},
#        {'X': 0.3053740859031677, 'Y': 0.6598325967788696}]},
#      'Id': 'a397c5d5-7243-462d-8c94-c5f918dca390',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.37890625,
#      'RowIndex': 8,
#      'ColumnIndex': 3,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19070206582546234,
#        'Height': 0.016044847667217255,
#        'Left': 0.49700793623924255,
#        'Top': 0.6438585519790649},
#       'Polygon': [{'X': 0.49700793623924255, 'Y': 0.6438585519790649},
#        {'X': 0.687706470489502, 'Y': 0.6438935399055481},
#        {'X': 0.6877099871635437, 'Y': 0.6599034070968628},
#        {'X': 0.4970104992389679, 'Y': 0.659868061542511}]},
#      'Id': 'fdfdf756-5e33-42f8-86f9-ee1da9b024df',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.255859375,
#      'RowIndex': 8,
#      'ColumnIndex': 4,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19163066148757935,
#        'Height': 0.01604531891644001,
#        'Left': 0.687706470489502,
#        'Top': 0.6438935399055481},
#       'Polygon': [{'X': 0.687706470489502, 'Y': 0.6438935399055481},
#        {'X': 0.8793326616287231, 'Y': 0.6439287066459656},
#        {'X': 0.8793371319770813, 'Y': 0.6599388718605042},
#        {'X': 0.6877099871635437, 'Y': 0.6599034070968628}]},
#      'Id': '83c15c5e-a03a-42a1-9f14-e7e616dafd13',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.76953125,
#      'RowIndex': 9,
#      'ColumnIndex': 1,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1915600448846817,
#        'Height': 0.01637839712202549,
#        'Left': 0.11381568759679794,
#        'Top': 0.6597971320152283},
#       'Polygon': [{'X': 0.11381568759679794, 'Y': 0.6597971320152283},
#        {'X': 0.3053740859031677, 'Y': 0.6598325967788696},
#        {'X': 0.30537572503089905, 'Y': 0.6761755347251892},
#        {'X': 0.11381636559963226, 'Y': 0.676139771938324}]},
#      'Id': 'a9f5dc3e-18fc-4c29-817b-81f17a5a9b6a',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['1621ae68-3b79-4c3d-a400-3340aec56586']}],
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.037109375,
#      'RowIndex': 9,
#      'ColumnIndex': 2,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1916390061378479,
#        'Height': 0.016378717496991158,
#        'Left': 0.3053740859031677,
#        'Top': 0.6598325967788696},
#       'Polygon': [{'X': 0.3053740859031677, 'Y': 0.6598325967788696},
#        {'X': 0.4970104992389679, 'Y': 0.659868061542511},
#        {'X': 0.4970130920410156, 'Y': 0.6762112975120544},
#        {'X': 0.30537572503089905, 'Y': 0.6761755347251892}]},
#      'Id': '84e89d72-c7f6-4541-bb98-4b984a3a140e',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 88.427734375,
#      'RowIndex': 9,
#      'ColumnIndex': 3,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19070307910442352,
#        'Height': 0.016378849744796753,
#        'Left': 0.4970104992389679,
#        'Top': 0.659868061542511},
#       'Polygon': [{'X': 0.4970104992389679, 'Y': 0.659868061542511},
#        {'X': 0.6877099871635437, 'Y': 0.6599034070968628},
#        {'X': 0.6877135634422302, 'Y': 0.6762469410896301},
#        {'X': 0.4970130920410156, 'Y': 0.6762112975120544}]},
#      'Id': 'af8ccaea-4958-450e-bd6c-7f0515e83601',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 87.3046875,
#      'RowIndex': 9,
#      'ColumnIndex': 4,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19163170456886292,
#        'Height': 0.016379326581954956,
#        'Left': 0.6877099871635437,
#        'Top': 0.6599034070968628},
#       'Polygon': [{'X': 0.6877099871635437, 'Y': 0.6599034070968628},
#        {'X': 0.8793371319770813, 'Y': 0.6599388718605042},
#        {'X': 0.8793416619300842, 'Y': 0.6762827038764954},
#        {'X': 0.6877135634422302, 'Y': 0.6762469410896301}]},
#      'Id': 'f879653a-ca90-44f5-bcb0-8ea322d41bf9',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 91.162109375,
#      'RowIndex': 10,
#      'ColumnIndex': 1,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1915610432624817,
#        'Height': 0.016625192016363144,
#        'Left': 0.11381636559963226,
#        'Top': 0.676139771938324},
#       'Polygon': [{'X': 0.11381636559963226, 'Y': 0.676139771938324},
#        {'X': 0.30537572503089905, 'Y': 0.6761755347251892},
#        {'X': 0.30537742376327515, 'Y': 0.6927649974822998},
#        {'X': 0.11381705105304718, 'Y': 0.6927288770675659}]},
#      'Id': 'd730ea51-db05-427a-aa40-50a4603d9ae7',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['1e27a8c8-c58f-41a0-a03f-a519ea469dfc']}],
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 90.4296875,
#      'RowIndex': 10,
#      'ColumnIndex': 2,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.19164001941680908,
#        'Height': 0.01662551797926426,
#        'Left': 0.30537572503089905,
#        'Top': 0.6761755347251892},
#       'Polygon': [{'X': 0.30537572503089905, 'Y': 0.6761755347251892},
#        {'X': 0.4970130920410156, 'Y': 0.6762112975120544},
#        {'X': 0.49701574444770813, 'Y': 0.6928010582923889},
#        {'X': 0.30537742376327515, 'Y': 0.6927649974822998}]},
#      'Id': '95ee3e98-5f63-46e0-99e7-c258ba4c6e34',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 90.771484375,
#      'RowIndex': 10,
#      'ColumnIndex': 3,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1907040923833847,
#        'Height': 0.016625652089715004,
#        'Left': 0.4970130920410156,
#        'Top': 0.6762112975120544},
#       'Polygon': [{'X': 0.4970130920410156, 'Y': 0.6762112975120544},
#        {'X': 0.6877135634422302, 'Y': 0.6762469410896301},
#        {'X': 0.6877171993255615, 'Y': 0.6928369998931885},
#        {'X': 0.49701574444770813, 'Y': 0.6928010582923889}]},
#      'Id': 'e7bdfd8a-4570-453e-b815-72261a4c30e4',
#      'Page': 4},
#     {'BlockType': 'CELL',
#      'Confidence': 89.6484375,
#      'RowIndex': 10,
#      'ColumnIndex': 4,
#      'RowSpan': 1,
#      'ColumnSpan': 1,
#      'Geometry': {'BoundingBox': {'Width': 0.1916327327489853,
#        'Height': 0.016626136377453804,
#        'Left': 0.6877135634422302,
#        'Top': 0.6762469410896301},
#       'Polygon': [{'X': 0.6877135634422302, 'Y': 0.6762469410896301},
#        {'X': 0.8793416619300842, 'Y': 0.6762827038764954},
#        {'X': 0.8793463110923767, 'Y': 0.6928730607032776},
#        {'X': 0.6877171993255615, 'Y': 0.6928369998931885}]},
#      'Id': 'f4119f7d-f47b-450b-b6d2-5d9c3a72bccc',
#      'Page': 4},
#     {'BlockType': 'TABLE_TITLE',
#      'Confidence': 86.328125,
#      'Geometry': {'BoundingBox': {'Width': 0.1563364565372467,
#        'Height': 0.04188206419348717,
#        'Left': 0.4189319908618927,
#        'Top': 0.08652074635028839},
#       'Polygon': [{'X': 0.4189319908618927, 'Y': 0.08652074635028839},
#        {'X': 0.5752606987953186, 'Y': 0.08654092252254486},
#        {'X': 0.5752684473991394, 'Y': 0.12840281426906586},
#        {'X': 0.41893768310546875, 'Y': 0.12838199734687805}]},
#      'Id': '99215ca5-db09-48c7-a780-1808d7085c4e',
#      'Relationships': [{'Type': 'CHILD',
#        'Ids': ['a29b614c-dad7-474a-90c1-b4e2edf751de',
#         '35ac90ec-15c8-49fa-acb4-0fb58c3cdcde',
#         '5e00249f-d5bf-45f7-afab-0cf79c201917',
#         '5f7bacd0-8ba0-4592-9215-c694383551f6',
#         '65284d81-91aa-4c2d-9f28-0c1d570aff08',
#         '8a2e9f88-69d9-469a-a1f6-59df31f4cc4b',
#         '322427b6-ba36-4f34-b213-d8ebddc6db23']}],
#      'Page': 4}],
#    'AnalyzeDocumentModelVersion': '1.0',
#    'ResponseMetadata': {'RequestId': 'ad000c51-6040-42f3-a961-f74162566244',
#     'HTTPStatusCode': 200,
#     'HTTPHeaders': {'x-amzn-requestid': 'ad000c51-6040-42f3-a961-f74162566244',
#      'content-type': 'application/x-amz-json-1.1',
#      'content-length': '265982',
#      'date': 'Thu, 06 Jul 2023 15:03:24 GMT'},
#     'RetryAttempts': 0}}]]

# %%
json_file_path = "tesseract_result.json"
f = open(json_file_path, 'r')

# returns JSON object as a dictionary
result = json.load(f)

# %% [markdown]
# # **Transformation**
#
# After getting test result from AWS Tesseract, below code transforms it into the desired format.
# At the end of code a CSV File is generated.

# %%
def get_text(words, lines):
    symbols, boxes = list(), list()
    for word in words.values():
        symbol = word["Text"]
        if symbol and len(symbol) > 0.5:
            symbols.append(symbol)
            boxes.append(word["Geometry"]["BoundingBox"])

    text = list()
    for line in lines.values():
        text.append(line["Text"])
    return symbol, boxes, text

def get_children_ids(block):
    for rels in block.get('Relationships', []):
        if rels['Type'] == 'CHILD':
            yield from rels['Ids']

def map_blocks(blocks, block_type):
    return {
        block['Id']: block
        for block in blocks
        if block['BlockType'] == block_type
    }

def get_tables_df(tables, cells, words, selections):
    dataframes = []
    for table in tables.values():
        # Determine all the cells that belong to this table
        table_cells = [cells[cell_id] for cell_id in get_children_ids(table)]
        # Determine the table's number of rows and columns
        n_rows = max(cell['RowIndex'] for cell in table_cells)
        n_cols = max(cell['ColumnIndex'] for cell in table_cells)
        content = [[None for _ in range(n_cols)] for _ in range(n_rows)]

        # Fill in each cell
        for cell in table_cells:
            cell_contents = [
                words[child_id]['Text']
                if child_id in words
                else selections[child_id]['SelectionStatus']
                for child_id in get_children_ids(cell)
            ]
            i = cell['RowIndex'] - 1
            j = cell['ColumnIndex'] - 1
            content[i][j] = ' '.join(cell_contents)

        # We assume that the first row corresponds to the column names
        dataframe = pd.DataFrame(content[0:], columns=content[0])
        dataframes.append([dataframe, table["Page"]])
    return dataframes

# %%
def transform_dataset(df):
    values_to_filter = ['Run hours', 'Consumption']
    # Select rows based on values in a list
    df = df[df['Details'].isin(values_to_filter)]
    # print(df[df['Details'].isin(values_to_filter)])
    system = [1, 1, 2, 2, 3, 3, 4, 4]
    df["System"] = system[:len(df)]
    # print( system[:len(df)])
    df = df[["System", "Details", "3rd", "1st", "2nd"]]
    pivot_df = df.pivot(index='System', columns='Details').swaplevel(0, 1, 1).sort_index(axis=1)
    single_row_df = pivot_df.unstack().to_frame().transpose()
    single_row_df.columns = ['_'.join(map(str, col)) for col in single_row_df.columns]
    new_cols = ['Run hours_3rd_1', 'Consumption_3rd_1', 'Run hours_1st_1', 'Consumption_1st_1', 'Run hours_2nd_1',
                'Consumption_2nd_1', 'Run hours_3rd_2', 'Consumption_3rd_2', 'Run hours_1st_2', 'Consumption_1st_2',
                'Run hours_2nd_2', 'Consumption_2nd_2', 'Run hours_3rd_3', 'Consumption_3rd_3', 'Run hours_1st_3',
                'Consumption_1st_3', 'Run hours_2nd_3', 'Consumption_2nd_3', 'Run hours_3rd_4', 'Consumption_3rd_4',
                'Run hours_1st_4', 'Consumption_1st_4', 'Run hours_2nd_4', 'Consumption_2nd_4']
    single_row_df = single_row_df.reindex(columns = new_cols)
    single_row_df = single_row_df.fillna(0)
    return single_row_df

# %%
import re

def clean_and_convert_dates(date_list):
    cleaned_dates = []
    for sublist in date_list:
        date_str = ' '.join(sublist[1:])
        date = date_str.replace('.',' ')
        date = date.split(" ")
        while('' in date):
          date.remove('')
        date = f"{date[0]} {date[1]} {date[2]}"
        cleaned_date = datetime.strptime(date, "%d %b %Y").date()
        cleaned_dates.append(cleaned_date)

    return cleaned_dates

def extract_date(word_list, start_token, stop_token):
    is_extraction_started = False
    extracted_words = []

    for word in word_list:
        if fuzz.ratio(word.lower(), start_token) >= 80:
            is_extraction_started = True
        elif fuzz.ratio(word.lower(), stop_token) >= 80:
            is_extraction_started = False

        if is_extraction_started:
            extracted_words.append(word)

    return extracted_words

def get_date(words, total_pages):
    uncleaned_dates = []

    for value in range(total_pages):
        selected_arrays = [sub_array for sub_array in words if len(sub_array) > 1 and sub_array[1] == value+1]
        first_elements = [sub_array[0] for sub_array in selected_arrays]
        uncleaned_dates.append(extract_date(first_elements, "date", "operator"))

    return clean_and_convert_dates(uncleaned_dates)

# %%
master_df = pd.DataFrame(columns = ['Run hours_3rd_1', 'Consumption_3rd_1', 'Run hours_1st_1', 'Consumption_1st_1', 'Run hours_2nd_1',
                'Consumption_2nd_1', 'Run hours_3rd_2', 'Consumption_3rd_2', 'Run hours_1st_2', 'Consumption_1st_2',
                'Run hours_2nd_2', 'Consumption_2nd_2', 'Run hours_3rd_3', 'Consumption_3rd_3', 'Run hours_1st_3',
                'Consumption_1st_3', 'Run hours_2nd_3', 'Consumption_2nd_3', 'Run hours_3rd_4', 'Consumption_3rd_4',
                'Run hours_1st_4', 'Consumption_1st_4', 'Run hours_2nd_4', 'Consumption_2nd_4'])
blocks = []
dates = []
total_pages = 0
tables = {}
cells = {}
words = {}
lines = {}
selections = {}
for page in result[0]:
    blocks.append(page["Blocks"])
    total_pages = page["DocumentMetadata"]["Pages"]

blocks = list(itertools.chain.from_iterable(blocks))

tables.update(map_blocks(blocks, 'TABLE'))
cells.update(map_blocks(blocks, 'CELL'))
words.update(map_blocks(blocks, 'WORD'))
lines.update(map_blocks(blocks, 'LINE'))
selections.update(map_blocks(blocks, 'SELECTION_ELEMENT'))

page_words = []
for word in words.values():
    page_words.append([word["Text"], word["Page"]])

dates = get_date(page_words, total_pages)
# print(dates)

dataframes = get_tables_df(tables=tables,
                           cells=cells,
                           words=words,
                           selections=selections)
# print(dataframes)
df_new = pd.DataFrame(columns=["Details", "3rd", "1st", "2nd"])


page_dataframes = {}

# Concatenate dataframes of the same page
for dataframe, page in dataframes:
    if len(dataframe.columns)!=4:
        continue
    # print(dataframe)
    # print(page)
    dataframe = pd.DataFrame(np.concatenate([df_new.values, dataframe.values], axis=0), columns=df_new.columns)
    if page not in page_dataframes:
        page_dataframes[page] = dataframe
    else:
        page_dataframes[page] = pd.concat([page_dataframes[page], dataframe])
# Transform each page's dataframe as a single row and append it to the master dataframe.
for page, dataframe in page_dataframes.items():
    single_row_dataset = transform_dataset(dataframe)
    master_df = pd.DataFrame(np.concatenate([master_df.values, single_row_dataset.values], axis=0),
                             columns=master_df.columns)

master_df["Date"] = dates
master_df = master_df[['Date', 'Run hours_3rd_1', 'Consumption_3rd_1', 'Run hours_1st_1', 'Consumption_1st_1', 'Run hours_2nd_1',
                'Consumption_2nd_1', 'Run hours_3rd_2', 'Consumption_3rd_2', 'Run hours_1st_2', 'Consumption_1st_2',
                'Run hours_2nd_2', 'Consumption_2nd_2', 'Run hours_3rd_3', 'Consumption_3rd_3', 'Run hours_1st_3',
                'Consumption_1st_3', 'Run hours_2nd_3', 'Consumption_2nd_3', 'Run hours_3rd_4', 'Consumption_3rd_4',
                'Run hours_1st_4', 'Consumption_1st_4', 'Run hours_2nd_4', 'Consumption_2nd_4']]

master_df = master_df.fillna('').replace('', 0)
master_df.to_csv("Final_Master_dataset.csv", index=False)
